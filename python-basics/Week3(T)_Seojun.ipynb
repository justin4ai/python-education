# %% [markdown]
# # Week 3 - Condition Statements and Loops

# %% [markdown]
# Created By Junyeong Ahn

# %% [markdown]
# **Goal1** : Python의 조건문(condition statement)인 if문을 익히자.
#
# **Goal2** : Python의 반복문(loop)인 while과, for에 대해서 익히자.

# %% [markdown]
# ## 1.If

# %% [markdown]
# ### if문의 기본 구조

# %% [markdown]
# 다음과 같은 상상을 해보자.
#
# `"돈이 있으면 택시를 타고, 돈이 없으면 걸어 간다."`
#
# 우리 모두에게 일어날 수 있는 상황 중 하나이다. 프로그래밍도 사람이 하는 것이므로 위 문장처럼 주어진 조건을 판단한 후 그 상황에 맞게 처리해야 할 경우가 생긴다. 이렇듯 프로그래밍에서 조건을 판단하여 해당 조건에 맞는 상황을 수행하는 데 쓰는 것이 바로 **if문**이다.
#
# 위와 같은 상황을 파이썬에서는 다음과 같이 표현할 수 있다.

# %%
money = 있다

if money = 있다
    print("택시를 타고 가라")
else,
    print("걸어 가라")

# 택시를 타고 가라

# %% [markdown]
# - 위와 같이 Python 문법에는 맞지 않으나, 개략적으로 자신이 구현하고자 하는 코드를 표현한 것을 **pseudocode**라고 한다.

# %% [markdown]
# if 조건문에서 "조건문"이란 참과 거짓을 판단하는 문장을 말한다.
#
# 앞에서 살펴본 택시 예제에서 조건문은 money가 된다.

# %%
money = True
if money:
  print("Money money")

# %% [markdown]
# ###What's Condition Statement?

# %% [markdown]
# 다음과 같은 비교 연산자들은 결과값으로 Bool type을 반환하기 때문에, if 조건문에서 가장 많이 보이는 표현 중 하나다.
#
# ![image.png](data:image/png;base64,...)

# %%
if 'Seojun' == 'Justin':
  print("I am Justin")

# %%
if 155 != '155':
  print("We are different")

# %% [markdown]
# ### Indentation

# %% [markdown]
# if문을 만들 때는 if 조건문: 바로 아래 문장부터 if문에 속하는 모든 문장에 들여쓰기(indentation)를 해주어야 한다
#
#  아래에서 보는 것과 같이 조건문이 참일 경우 "수행할 문장1"을 들여쓰기했고 "수행할 문장2"와 "수행할 문장3"도 들여쓰기 해 주었다.

# %%
if 조건문:
    수행할 문장1
    수행할 문장2
    수행할 문장3

# %% [markdown]
# 다음처럼 작성하면 오류가 발생한다. "수행할 문장2"를 들여쓰기하지 않았기 때문이다.

# %%
if 조건문:
    수행할 문장1
수행할 문장2
    수행할 문장3

# %%
money = True
if money:
    print("택시를")
print("타고")
    print("가라")

# %% [markdown]
# ### Try It! 1

# %% [markdown]
# "만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 그렇지 않으면 걸어 가라."
# 라는 문장을, Python code로 표현하시오.

# %% [markdown]
# ### And, or and not

# %% [markdown]
# 조건을 판단하기 위해 사용하는 다른 연산자로는 and, or, not이 있다. 각각의 연산자는 다음처럼 동작한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 다음 예를 통해 or 연산자의 사용법을 알아보자.
#
# ```"돈이 3000원 이상 있거나 카드가 있다면 택시를 타고 그렇지 않으면 걸어 가라."```

# %%
money = 2000
card = True

# Write further codes

# %% [markdown]
# And와 or은, 각각 기호 &와 |로도 나타낼 수 있다.

# %% [markdown]
# 사실, &와 |는 이미 Week2 - Set에서, 각각 intersection와 union을 뜻하는 기호로 이미 소개되었다.

# %%
if (5 == 5) & (11 != 10):
  print("Both statements are correct.")

# %%
if (5 == 7) | (5 == 5):
  print("At least one of the statements must be correct.")

# %% [markdown]
# ### In and not in

# %% [markdown]
# 더 나아가 파이썬은 다른 프로그래밍 언어에서 쉽게 볼 수 없는 재미있는 조건문을 제공한다.
#
# 바로 다음과 같은 것들이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 특히 in의 경우, 지난 주 dictionary의 key에 포함되는지 아닌지를 확인하는 함수로서 사용할 수 있다고 학습했었다.

# %% [markdown]
# 영어 단어 in의 뜻이 "~안에"라는 것을 생각해 보면 다음 예가 쉽게 이해될 것이다.

# %%
1 in [1, 2, 3]


#1 not in [1, 2, 3]

# %%
'a' in ('a', 'b', 'c')

# 'j' not in 'python'

# %% [markdown]
# 이번에는 우리가 계속 사용해 온 택시 예제에 in을 적용해 보자.
#
# ```"만약 주머니에 돈이 있으면 택시를 타고, 없으면 걸어 가라."```

# %%
Pocket = ['paper', 'cellphone', 'money']

# Write further codes

# %% [markdown]
# ### 조건문에서 아무 일도 하지 않게 설정하고 싶다면?

# %% [markdown]
# 가끔 조건문의 참, 거짓에 따라 실행할 행동을 정의할 때, 아무런 일도 하지 않도록 설정하고 싶을 때가 있다.
#
# 다음 예를 보자.
#
# ```"주머니에 돈이 있으면 가만히 있고 주머니에 돈이 없으면 카드를 꺼내라."```
#
# 이럴 때 사용하는 것이 바로 **pass**이다. 위 예를 pass를 적용해서 구현해 보자.

# %%
pocket = ['paper', 'money', 'cellphone']

if 'money' in pocket:
    pass

     
else:
    print("카드를 꺼내라")

# %% [markdown]
# pocket 리스트 안에 money 문자열이 있기 때문에 if문 다음 문장인 pass가 수행되고 아무 결괏값도 보여 주지 않는다.

# %% [markdown]
# 혹은, 다음과 같이도 해볼 수 있으나 pass보다 비효율적이다.

# %%
pocket = ['paper', 'money', 'cellphone']

if 'money' in pocket:
    pocket = 5
     
else:
    print("카드를 꺼내라")

# %% [markdown]
# ### Elif

# %% [markdown]
# If와 else는, 그림으로 표현하자면 다음과 같다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 그렇다면, else 밑에 다시 if와 else를 쓰면, 다음과 같은 코드가 가능하다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 101

if x < -100 :
  print("Do A")

else : # all the cases within the range from -100 to ∞
  
  if (-100 <= x) and (x < 100) :
    print("Do B")

  else : # all the cases within the range from 100 to ∞
    print("Do C")

# %% [markdown]
# 언뜻 보기에도 이해하기 어렵고 산만한 느낌이 든다. 이런 복잡함을 해결하기 위해 파이썬에서는 다중 조건 판단을 가능하게 하는 elif를 사용한다.
#
# 위 예를 elif를 사용하면 다음과 같이 바꿀 수 있다.

# %%
x = 101

if x < -100 :
  print("Do A")

elif (-100 <= x) and (x < 100) :
  print("Do B")

else : # all the cases within the range from 100 to ∞
  print("Do C")

# %% [markdown]
# 즉 elif는 이전 조건문이 거짓일 때 수행된다. if, elif, else를 모두 사용할 때 기본 구조는 다음과 같다.

# %%
If <조건문>:
    <수행할 문장1> 
    <수행할 문장2>
    ...
elif <조건문>:
    <수행할 문장1>
    <수행할 문장2>
    ...
elif <조건문>:
    <수행할 문장1>
    <수행할 문장2>
    ...
...
else:
   <수행할 문장1>
   <수행할 문장2>
   ...

# %% [markdown]
# 위에서 볼 수 있듯이 elif는 개수에 제한 없이 사용할 수 있다.

# %% [markdown]
# ### Advanced - Conditional Expression

# %% [markdown]
# 다음과 같은 코드를 보자.

# %%
if score >= 60:
    message = "success"
else:
    message = "failure"

# %% [markdown]
# 위 코드는 score가 60 이상일 경우 message에 문자열 "success"를, 아닐 경우에는 "failure"를 대입하는 코드이다.
#
# 파이썬의 조건부 표현식(conditional expression)을 사용하면 위 코드를 다음과 같이 간단히 표현할 수 있다.

# %%
message = "success" if score >= 60 else "failure"

# %% [markdown]
# 조건부 표현식은 다음과 같이 정의한다.
#
# > 변수 = ```조건문이_참인_경우의_값 if 조건문 else 조건문이_거짓인_경우의_값```
#
# 조건부 표현식은 가독성에 유리하고 한 줄로 작성할 수 있어 활용성이 좋다.

# %% [markdown]
# ## 2.While Loop

# %% [markdown]
# ### while문의 기본 구조

# %% [markdown]
# 반복해서 문장을 수행해야 할 경우 while문을 사용한다. 그래서 while문을 반복문이라고도 부른다.
#
# 다음은 while문의 기본 구조이다.

# %%
while <조건문>:
    <수행할 문장1>
    <수행할 문장2>
    <수행할 문장3>
    ...

# %% [markdown]
# while문은 조건문이 참인 동안에 while문에 속한 문장들이 반복해서 수행된다.
#
# "열 번 찍어 안 넘어가는 나무 없다"는 속담을 파이썬 프로그램으로 만든다면 다음과 같이 될 것이다.

# %%
treeHit = 0
while treeHit < 10:

    treeHit = treeHit +1
    print("나무를 %d번 찍었습니다." % treeHit)

    if treeHit == 10:
        print("나무 넘어갑니다.")

    # else:
        # pass  .. 는 생략 가능!

#...
#나무를 1번 찍었습니다.
#나무를 2번 찍었습니다.
#나무를 3번 찍었습니다.
#나무를 4번 찍었습니다.
#나무를 5번 찍었습니다.
#나무를 6번 찍었습니다.
#나무를 7번 찍었습니다.
#나무를 8번 찍었습니다.
#나무를 9번 찍었습니다.
#나무를 10번 찍었습니다.
#나무 넘어갑니다.

# %% [markdown]
# 위 예에서 while문의 조건문은 treeHit < 10이다. 즉 treeHit가 10보다 작은 동안에 while문에 포함된 문장들을 계속 수행한다. whlie문 안의 문장을 보면 제일 먼저 **treeHit = treeHit + 1**로 **treeHit 값이 계속 1씩 증가**한다.
#
# 그리고 나무를 treeHit번만큼 찍었음을 알리는 문장을 출력하고 treeHit가 10이 되면 "나무 넘어갑니다."라는 문장을 출력한다.
#
# 그러고 나면 treeHit < 10 조건문이 거짓이 되므로 while문을 빠져나가게 된다.

# %% [markdown]
# > treeHit = treeHit + 1은 프로그래밍을 할 때 매우 자주 사용하는 기법이다. treeHit 값을 1만큼씩 증가시킬 목적으로 사용하며, treeHit += 1 처럼 사용해도 된다 = increment.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### while문 만들기

# %% [markdown]
# 이번에는 여러 가지 선택지 중 하나를 선택해서 입력받는 예제를 만들어 보자. 먼저 다음과 같이 여러 줄짜리 문자열인 prompt를 만들자.

# %%
prompt = """
1. Add
2. Del
3. List
4. Quit
Enter number: """

# %% [markdown]
# 이어서 number 변수에 0을 먼저 대입한다. 이렇게 변수를 먼저 설정해 놓지 않으면 다음에 나올 while문의 조건문인 number != 4에서 변수가 존재하지 않는다는 오류가 발생한다.

# %%
number = 0
while number != 4:
  
    print(prompt)
    number = int(input())

# %% [markdown]
# ### How to escape the loop

# %% [markdown]
# while문은 조건문이 참인 동안 계속해서 while문 안의 내용을 반복적으로 수행한다.
#
# 하지만 강제로 while문을 빠져나가고 싶을 때가 있다.
#
# <br><br>
#
# 예를 들어 커피 자판기를 생각해 보자. 자판기 안에 커피가 충분히 있을 때에는 동전을 넣으면 커피가 나온다.
#
# 그런데 자판기가 제대로 작동하려면 커피가 얼마나 남았는지 항상 검사해야 한다.
#
#  만약 커피가 떨어졌다면 판매를 중단하고 "판매 중지" 문구를 사용자에게 보여주어야 한다.
#
# <br><br>이렇게 판매를 강제로 멈추게 하는 것이 바로 **break문**이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
coffee = 10
money = 300
while money:

    print("돈을 받았으니 커피를 줍니다.")

    coffee = coffee -1

    print("남은 커피의 양은 %d개입니다." % coffee) # Do you remember what formatting is?

    if coffee == 0:
      
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break

# %% [markdown]
# ### How to get back to the first line of while loop

# %% [markdown]
# while문 안의 문장을 수행할 때 입력 조건을 검사해서 조건에 맞지 않으면 while문을 빠져나간다.
#
# 그런데 프로그래밍을 하다 보면 while문을 빠져나가지 않고 while문의 맨 처음(조건문)으로 다시 돌아가게 만들고 싶은 경우가 생기게 된다. 이때 사용하는 것이 바로 continue문이다.<br><br>
#
# 1부터 10까지의 숫자 중에서 홀수만 출력하는 것을 while문을 사용해서 작성한다고 생각해보자. 어떤 방법이 좋을까?

# %%
a = 0

while a < 10:

    a = a + 1
    if a % 2 == 0: continue # 실행문이 한 줄인 경우에는, 콜론 옆에 붙여 쓸 수 있다.
    
    print(a)

# %% [markdown]
# 위 예는 1부터 10까지의 숫자 중 홀수만 출력하는 예이다.
#
# a가 10보다 작은 동안 a는 1만큼씩 계속 증가한다.
#
# if a % 2 == 0(a를 2로 나누었을 때 나머지가 0인 경우)이 참이 되는 경우는 a가 짝수일 때이다.
# <br><br>
# 즉 a가 짝수이면 continue 문장을 수행한다.
#
# 이 continue문은 while문의 맨 처음(조건문: a<10)으로 돌아가게 하는 명령어이다. 따라서 위 예에서 a가 짝수이면 print(a) 문장은 수행되지 않을 것이다.

# %% [markdown]
# ### Infinite Loop

# %% [markdown]
# 무한 루프란 무한히 반복한다는 의미이다. 우리가 사용하는 일반 프로그램 중에서 무한 루프 개념을 사용하지 않는 프로그램은 거의 없다. 그만큼 자주 사용한다는 뜻이다.

# %%
while True: 
    수행할 문장1 
    수행할 문장2
    ...

# %% [markdown]
# while문의 조건문이 True이므로 항상 참이 된다. 따라서 while문 안에 있는 문장들은 무한하게 수행될 것이다.
#
# 다음의 무한 루프 예이다.

# %%
while True:
    print("Ctrl+M+I를 눌러야 while문을 빠져나갈 수 있습니다.")

#Ctrl+M+I를 눌러야 while문을 빠져나갈 수 있습니다.
#Ctrl+M+I를 눌러야 while문을 빠져나갈 수 있습니다.
#Ctrl+M+I를 눌러야 while문을 빠져나갈 수 있습니다.
#....

# %% [markdown]
# ### Try It!

# %% [markdown]
# While loop를 사용하여, 1, 3, 6, 10, 15를 순서대로 print하는 코드를 작성하시오.

# %% [markdown]
# ## 3.For Loop

# %% [markdown]
# 파이썬의 직관적인 특징을 가장 잘 보여주는 것이 바로 이 for문이다. while문과 비슷한 반복문인 for문은 문장 구조가 한눈에 쏙 들어온다는 장점이 있다. for문을 잘 사용하면 프로그래밍이 즐거워질 것이다.

# %% [markdown]
# ### for문의 기본 구조

# %%
for 변수 in 리스트(또는 튜플, 문자열):
    수행할 문장1
    수행할 문장2
    ...

# %% [markdown]
# 리스트나 튜플, 문자열의 첫 번째 요소부터 마지막 요소까지 차례로 변수에 대입되어 "수행할 문장1", "수행할 문장2" 등이 수행된다.

# %% [markdown]
# **1. 전형적인 for문**

# %%
test_list = ['one', 'two', 'three'] 
for i in test_list: 
    print(i)

# %% [markdown]
# ['one', 'two', 'three'] 리스트의 첫 번째 요소인 'one'이 먼저 i 변수에 대입된 후 print(i) 문장을 수행한다.
#
# 다음에 두 번째 요소 'two'가 i 변수에 대입된 후 print(i) 문장을 수행하고 리스트의 마지막 요소까지 이것을 반복한다.

# %% [markdown]
# **2. 다양한 for문의 사용**

# %%
a = [(1,2), (3,4), (5,6)]
for (first, last) in a:
    print(first + last)

# %% [markdown]
# 위 예는 a 리스트의 요솟값이 튜플이기 때문에 각각의 요소가 자동으로 (first, last) 변수에 대입된다.

# %% [markdown]
# **3. for문의 응용**

# %% [markdown]
# 총 5명의 학생이 시험을 보았는데 시험 점수가 60점 이상이면 합격이고 그렇지 않으면 불합격이다. 합격인지 불합격인지 결과를 보여 주시오.

# %% [markdown]
# 우선 학생 5명의 시험 점수를 리스트로 표현해 보자.

# %%
marks = [90, 25, 67, 45, 80]

# %% [markdown]
# 1번 학생은 90점이고 5번 학생은 80점이다.
#
# 이런 점수를 차례로 검사해서 합격했는지 불합격했는지 통보해 주는 프로그램을 만들어 보자.

# %%
marks = [90, 25, 67, 45, 80]

number = 0 
for mark in marks: 
    number = number +1 
    if mark >= 60: 
        print("%d번 학생은 합격입니다." % number)
    else: 
        print("%d번 학생은 불합격입니다." % number)

# %% [markdown]
# 각각의 학생에게 번호를 붙여 주기 위해 number 변수를 사용하였다.
#
# 점수 리스트 marks에서 차례로 점수를 꺼내어 mark라는 변수에 대입하고 for문 안의 문장들을 수행한다.
#
# 우선 for문이 한 번씩 수행될 때마다 number는 1씩 증가한다.

# %% [markdown]
# ### Continue

# %% [markdown]
# while문에서 살펴본 **continue문**을 for문에서도 사용할 수 있다.
#
# 즉, for문 안의 문장을 수행하는 도중에 continue문을 만나면 for문의 처음으로 돌아가게 된다.
#
# 앞에서 for문 응용 예제를 그대로 사용해서 60점 이상인 사람에게는 축하 메시지를 보내고, 나머지 사람에게는 아무 메시지도 전하지 않는 프로그램을 작성해 보자.

# %%
marks = [90, 25, 67, 45, 80]

number = 0 
for mark in marks: 
    number = number +1 
    if mark < 60:
        continue 
    print("%d번 학생 축하합니다. 합격입니다. " % number)

# %% [markdown]
# 점수가 60점 이하인 학생일 경우에는 mark < 60이 참이 되어 continue문이 수행된다. 따라서 축하 메시지를 출력하는 부분인 print문을 수행하지 않고 for문의 처음으로 돌아가게 된다.

# %% [markdown]
# ### Range function

# %% [markdown]
# for문은 숫자 리스트를 자동으로 만들어 주는 range 함수와 함께 사용하는 경우가 많다. 다음은 range 함수의 간단한 사용법이다.

# %%
a = range(10)

a

# type(a)

# %% [markdown]
# range(10)은 0부터 10 미만의 숫자를 포함하는 range 객체를 만들어 준다.

# %% [markdown]
# 시작 숫자와 끝 숫자를 지정하려면 **range(시작 숫자, 끝 숫자)** 형태를 사용하는데, 이때 끝 숫자는 포함되지 않는다 - slicing에서와 마찬가지로.

# %%
a = range(1, 11)

a

# %% [markdown]
# Slicing에서 그랬듯이, range function도 **step size**를 조절할 수 있다.

# %%
a = range(1, 11, 2)

a

# %% [markdown]
# ### Range function examples

# %% [markdown]
# for와 range 함수를 사용하면 1부터 10까지 더하는 것을 다음과 같이 쉽게 구현할 수 있다.

# %%
add = 0 
for i in range(1, 11): 
    add = add + i 

print(add)

# %% [markdown]
# range(1, 11)은 숫자 1부터 10까지(1 이상 11 미만)의 숫자를 데이터로 갖는 객체이다.
#
# 따라서 위 예에서 i 변수에 숫자가 1부터 10까지 하나씩 차례로 대입되면서 add = add + i 문장을 반복적으로 수행하고 add는 최종적으로 55가 된다.

# %% [markdown]
# 또한 우리가 앞에서 살펴본 "60점 이상이면 합격"이라는 문장을 출력하는 예제도 range 함수를 사용해서 다음과 같이 바꿀 수 있다.

# %%
marks = [90, 25, 67, 45, 80]
for number in range(len(marks)):
    if marks[number] < 60: 
        continue
    print("%d번 학생 축하합니다. 합격입니다." % (number+1))

# %% [markdown]
# len 함수는 list의 (# of elements)를 return하는 함수이다. 따라서 len(marks)는 5가 될 것이고, range(len(marks))는 range(5)가 될 것이다.
#
# number 변수에는 차례로 0부터 4까지의 숫자가 대입될 것이고, marks[number]는 차례대로 90, 25, 67, 45, 80 값을 갖게 된다.

# %% [markdown]
# ### Try It! - 구구단

# %% [markdown]
# for와 range 함수를 사용하면 소스 코드 단 4줄만으로 구구단을 출력할 수 있다.
#
# 들여쓰기에 주의하며 입력해 보자.

# %%
for i in range(2,10):        # 1번 for문
    for j in range(1, 10):   # 2번 for문
        print(i*j, end=" ") 
    print('')

# %% [markdown]
# 위 예를 보면 for문을 두 번 사용했다. 1번 for문에서 2부터 9까지의 숫자(range(2, 10))가 차례로 i에 대입된다. i가 처음 2일 때 2번 for문을 만나게 된다. 2번 for문에서 1부터 9까지의 숫자(range(1, 10))가 j에 대입되고 그다음 문장 print(i*j)를 수행한다.
#
# 따라서 i가 2일 때 2*1, 2*2, 2*3, … 2*9까지 차례로 수행되며 그 값을 출력하게 된다. 그다음으로 i가 3일 때 역시 2일 때와 마찬가지로 수행될 것이고 i가 9일 때까지 계속 반복된다. 그리고 print(i*j, end=" ")와 같이 print 함수에 end 파라미터를 설정한 이유는, 해당 결괏값을 출력할 때 다음줄로 넘기지 않고 그 줄에 계속해서 출력하기 위해서이다.
#
# <br><br>
# print 문의 end 매개변수에는 default로 줄바꿈 문자(\n)가 세팅되어 있다.
# 그다음에 이어지는 print(' ')는 2단, 3단 등을 구분하기 위해 사용했다. 두 번째 for문이 끝나면 결괏값을 다음 줄부터 출력하게 하는 역할을 한다.|

# %% [markdown]
# # Homework

# %% [markdown]
# Q1. Print창에, 다음과 같은 그림이 나오도록 코드를 작성해보자.
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Write your codes

# %% [markdown]
# Answer

# %%
for i in range(1, 5 + 1):
  for j in range(i):
    print('*', end = " ")
  print("")

# %% [markdown]
# Q2. Aimee는 변수를 여러 개 만들고 싶다.
#
# 예를 들어, 어떤 그룹에 멤버가 1000명 있다고 하자.
#
# <br><br>
#
# Aimee는, ith_person = "Hi, i'm the ith member of the group" 꼴로 string을 저장하는 변수 1000개를 for loop를 통해 만들기 위해 다음과 같이 시도했다.
#
# ```python
# ### Using f-string formatting ###
#
# for i in range(1, 1001):
#   f"{i}th_person" = f"Hi, i'm the {i}th member of the group"
# ```
#
# 하지만, 변수 이름은 formatting으로 지정할 수 없다는 에러를 받게 되었다.
#
# 즉, i에 따라 변수의 이름도 바뀌어야 하는데, 일반적인 방법으로는 자동 생성이 불가한 것이다.

# %% [markdown]
# 이 아이디어의 alternative가 될 수 있는 코드를 작성하시오. 즉, 1000개의 변수를 for loop으로 만들지는 못하더라도, 유사한 기능을 할 수 있는 코드를 작성하시오.
#
#  - Hint 1: 지금까지 배웠던 data type들을 잘 떠올려보자.
#  - Hint 2: 1 ~ 1000이 각각 1st ~ 1000th를 의미한다고 가정하면, 1 ~ 1000이 id의 역할을 할 수 있을지도?

# %%
# Write your codes

# %% [markdown]
# Answer

# %%
data = [None] + [0] * 1000

for i in range(1, 1001):
  data[i] = f"Hi, i'm the {i}th member of the group"

# %%
data = [f"Hi, i'm the {i}th member of the group" for i in range(1, 1001) ]

# %% [markdown]
# Q3. Input으로 받은 문장에 'advertisement' 혹은 'Advertisement' 라는 단어가 있으면 '문장 is spam.'을 print하고, 둘 다 없으면 '문장 is legitimate.'를 print하는 코드를 작성하시오.
#
# <예시>
#
# ```
# 문장 : adskflj;asd ijoipsdfus sstadvertisement__0asdal; //
#
# Print 결과 : adskflj;asd ijoipsdfus sstadvertisement__0asdal; // is spam.
# ```

# %% [markdown]
# Answer

# %%
sentence = str(input())

if 'advertisement' in sentence:
  print('spam')

else:
  print('legitimate')
