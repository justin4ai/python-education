# %% [markdown]
# # Week 1 - Python Data Types #1

# %% [markdown]
# **Goal** : Python의 다음과 같은 자료형들을 익히자; number, string, list and tuple.

# %% [markdown]
# ## 1.Number

# %% [markdown]
# 숫자형(Number)이란 숫자 형태로 이루어진 자료형으로, 우리가 이미 잘 알고 있는 것이다. 우리가 흔히 사용하는 숫자들을 생각해 보자. 123 같은 정수, 12.34 같은 실수, 드물게 사용하긴 하지만 8진수(octal number)나 16진수(hexadecimal) 같은 것도 있다.
#
# 다음 표는 파이썬에서 숫자를 어떻게 사용하는지 간략하게 보여 준다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Integer

# %% [markdown]
# 정수형(Integer)이란 말 그대로 정수를 뜻하는 자료형을 말한다. 다음 예는 양의 정수와 음의 정수, 숫자 0을 변수 a에 대입하는 예이다.

# %%
a = 123

a = -178

a = 0

# %% [markdown]
# ### Float

# %% [markdown]
# 파이썬에서 실수형(Floating-point)은 소수점이 포함된 숫자를 말한다. 다음은 실수를 변수 a에 대입하는 예이다.

# %%
a = 1.2

a = -3.45

# %% [markdown]
# 위 방식은 우리가 일반적으로 볼 수 있는 실수형의 소수점 표현 방식이다.

# %%
a = 4.24E10

a = 4.24e-10

# %% [markdown]
# 위 방식은 "컴퓨터식 지수 표현 방식"으로 파이썬에서는 4.24e10 또는 4.24E10처럼 표현한다(e와 E 둘 중 어느 것을 사용해도 상관없다).
#
# 여기서 4.24E10은 ![image.png](data:image/png;base64,...), 4.24e-10은 ![image.png](data:image/png;base64,...)을 의미한다.

# %% [markdown]
# ### Octal number & Hexadecimal

# %% [markdown]
# 8진수(Octal)를 만들기 위해서는 숫자가 0o 또는 0O(숫자 0 + 알파벳 소문자 o 또는 대문자 O)로 시작하면 된다.

# %%
a = 0o177

# %% [markdown]
# 16진수(Hexadecimal)를 만들기 위해서는 0x로 시작하면 된다.

# %%
a = 0x8ff
b = 0xABC

# %% [markdown]
# * Python에서 거의 사용하지 않는 숫자 자료형이니, 참고하고 넘어갑시다.

# %% [markdown]
# ### 사칙연산

# %% [markdown]
# 기본 네 가지; 덧셈, 뺄셈, 곱셈 그리고 나눗셈

# %%
a = 3
b = 4


### 덧셈 ###
print(a + b)

### 뺄셈 ###
#print(a - b)

### 곱셈 ###
#print(a * b)

### 나눗셈 ###
#print(a / b)

# %% [markdown]
# 제곱, 나머지 그리고 몫

# %%
a = 2
b = 5


### 제곱 ###
print(a ** b)

### 나머지 ###
#print(7 % 3)
#print(3 % 7)

### 몫 ###
#print(7 // 4)
#print(4 // 7)

# %% [markdown]
# ### Try It!

# %% [markdown]
# 1179로 18543를 나누었을 때, **Q**uotient와 **R**emainder를 구하세요.

# %%
# Print the Q


# Print the R

# %% [markdown]
# ## 2.String

# %% [markdown]
# 문자열(String)이란 문자, 단어 등으로 구성된 문자들의 집합을 의미한다. 예를 들어 다음과 같은 것들이 문자열이다.
#
# 따옴표로 둘러싸여 있으면 모두 문자열이라고 보면 된다.

# %%
"Life is too short, You need Python"
"a"
"123"

# %% [markdown]
# 1. 작은따옴표

# %%
'Python is fun'

# %% [markdown]
# 2. 큰따옴표

# %%
"Hello World"

# %% [markdown]
# 3.큰따옴표 x 3

# %%
"""Life is too short, You need python"""

# %% [markdown]
# 4.작은따옴표 x 3

# %%
'''Life is too short, You need python'''

# %% [markdown]
# 따옴표 안에 따옴표가 들어갈 때, 파이썬이 인식할 수 있도록 하기 위헤서 방법이 4가지나 있는 것!

# %%
say = '"Python is very easy." he says.'

# %%
food = "Python's favorite food is perl"

# %% [markdown]
# 혹은 백슬래시를 사용해서 작은따옴표(')와 큰따옴표(")를 문자열에 포함시키기

# %%
food = 'Python\'s favorite food is perl'
say = "\"Python is very easy.\" he says."

# %% [markdown]
# ### 이스케이프 코드

# %% [markdown]
# 이스케이프 코드란 프로그래밍할 때 사용할 수 있도록 미리 정의해 둔 "문자 조합"이다. 주로 출력물을 보기 좋게 정렬하는 용도로 사용한다. 몇 가지 이스케이프 코드를 정리하면 다음과 같다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Python is very easy. \n\n\n he says.")
# Out:
# Python is very easy.
#
#
#  he says.

# %%
print("Python is very easy. \t\t\t he says.")
# Out:
# Python is very easy. 			 he says.

# %% [markdown]
# ### 문자열 더하기 & 곱하기

# %% [markdown]
# 파이썬에서는 문자열을 더하거나 곱할 수 있다. 다른 언어에서는 쉽게 찾아볼 수 없는 재미있는 기능으로, 우리 생각을 그대로 반영해 주는 파이썬만의 장점이라고 할 수 있다.
#
# 문자열을 더하거나 곱하는 방법에 대해 알아보자.

# %% [markdown]
# 연결 (concatenation)

# %%
head = "Python"
tail = " is fun!"

print(head + tail)

# %% [markdown]
# 곱 (repetition)

# %%
a = "python"

print(a * 2)

# %% [markdown]
# ### Try It!

# %% [markdown]
# I love python so so so so so so much for real for real.
#
# 라는 문장을, 최소한의 코드로 print해보자!

# %%
# Try it!

# %% [markdown]
# 문자열의 길이는 다음과 같이 **len 함수**를 사용하면 구할 수 있다.
#
# len 함수는 print 함수처럼 파이썬의 기본 내장 함수로 별다른 설정 없이 바로 사용할 수 있다.

# %%
a = "Life is too short"

print(len(a))

# %% [markdown]
# ### Indexing

# %% [markdown]
# 인덱싱(Indexing) = 무엇인가를 "가리킨다"

# %%
a = "Life is too short, You need Python"

# %% [markdown]
# 위 소스 코드에서 변수 a에 저장한 문자열의 각 문자마다 번호를 매겨 보면 다음과 같다.

# %%
'''

Life is too short, You need Python
0         1         2         3 
0123456789012345678901234567890123

'''

# %% [markdown]
# "Life is too short, You need Python" 문자열에서 L은 첫 번째 자리를 뜻하는 숫자 0, 바로 다음인 i는 1 이런 식으로 계속 번호를 붙인 것이다.
#
# 중간에 있는 short의 s는 12가 된다.
#
#
# * 주의 : Python은 숫자를 0부터 센다!

# %%
a = "Life is too short, You need Python"

print(a[3])


#print(a[9])


#print(a[12])

# %% [markdown]
# Advanced - '-'가 인덱스에 붙으면 맨 뒤부터 거꾸로 카운트!

# %%
#print(a[-1])


#print(a[-15])


#print(a[-0])

# %% [markdown]
# ### Slicing

# %% [markdown]
# 그렇다면 "Life is too short, You need Python" 문자열에서 단순히 한 문자만을 뽑아내는 것이 아니라 'Life' 또는 'You' 같은 단어를 뽑아내는 방법은 없을까?

# %%
a = "Life is too short, You need Python"

# Without slicing
b = a[0] + a[1] + a[2] + a[3]
print(b)

# With slicing
print(a[0:4])

# %% [markdown]
# ```
# List[x : y]
#
# =>
#
# x <= a < y
#
# (a에 속하는 element들을 모두 slice)
#
# ```
#
# ![image.png](data:image/png;base64,...)

# %%
# Try more!

# %% [markdown]
# **시작 인덱스**, **끝 인덱스** 혹은 둘 모두 생략될 수 있다.

# %%
print(a[19:])

print(a[:17])

# %% [markdown]
# Indexing과 마찬가지로 (-) 기호를 사용할 수 있다.

# %%
print(a[19:-7])

# %% [markdown]
# ### Formatting

# %% [markdown]
# 문자열에서 또 하나 알아야 할 것으로는 문자열 포매팅(Formatting)이 있다. 이것을 공부하기 전에 다음과 같은 문자열을 출력하는 프로그램을 작성했다고 가정해 보자.
#
# **"현재 온도는 18도입니다."**
#
# 시간이 지나서 20도가 되면 다음 문장을 출력한다.
#
# **"현재 온도는 20도입니다"**
#
# 위 두 문자열은 모두 같은데 20이라는 숫자와 18이라는 숫자만 다르다. 이렇게 문자열 안의 특정한 값을 바꿔야 할 경우가 있을 때 이것을 가능하게 해주는 것이 바로 문자열 포매팅 기법이다.
#
# 쉽게 말해 문자열 포매팅이란 문자열 안에 어떤 값을 삽입하는 방법이다. 다음 예를 직접 실행해 보면서 그 사용법을 알아보자.

# %%
# 숫자 바로 대입

print("I eat %d apples." % 3)

# 문자열 바로 대입

#print("I eat %s apples." % "five")

# %% [markdown]
# 변수를 사용하면,

# %%
number = 3

print("I eat %d apples." % number)

# %% [markdown]
# 2개 이상의 값 사용

# %%
number = 10
day = "three"


print( "I ate %d apples. so I was sick for %s days." % (number, day) )

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 여기에서 재미있는 것은 %s 포맷 코드인데, 이 코드는 어떤 형태의 값이든 변환해 넣을 수 있다.

# %% [markdown]
# ### Formatting using 'format' function

# %%
print("I eat {0} apples".format(3))

#print("I eat {0} apples".format("five"))

# %%
number = 10
day = "three"


print( "I ate {0} apples. so I was sick for {1} days.".format(number, day) )

# %% [markdown]
# ### Fundamental functions

# %% [markdown]
# 문자 길이 세기(len)

# %%
a = "Seojun Lee"
len(a)

# %% [markdown]
# 문자 개수 세기(count)

# %%
a = "hobby"
a.count('b')

# %% [markdown]
# 위치 알려주기(find)

# %%
a = "Python is the best choice"
a.find('b')

# %% [markdown]
# 문자열 삽입(join)

# %%
",".join('abcd')

# %% [markdown]
# 문자열 바꾸기(replace)

# %%
a = "Life is too short"
a.replace("Life", "Your leg")

# %% [markdown]
# 문자열 나누기(split)

# %%
a = "Life is too short"
a.split()

# %% [markdown]
# ### (Advanced) F string

# %% [markdown]
# F-string의 모양은 f와 {}만 알면 된다.
#
# 문자열 맨 앞에 f를 붙여주고, 중괄호 안에 직접 변수 이름이나 출력하고 싶은것을 바로 넣으면 끝이다.

# %%
x = 2
y = "수학"

print(f"저는 하루에 {x}시간동안 {y}과목을 공부합니다.")

# %% [markdown]
# ## 3.List

# %% [markdown]
# 지금까지 우리는 숫자와 문자열에 대해서 알아보았다. 하지만 숫자와 문자열만으로 프로그래밍을 하기엔 부족한 점이 많다.
#
# 예를 들어 1부터 10까지의 숫자 중 홀수 모음인 1, 3, 5, 7, 9의 집합을 생각해 보자.
#
# 이런 숫자 모음을 숫자나 문자열로 표현하기는 쉽지 않다.
#
# 파이썬에는 이러한 불편함을 해소할 수 있는 자료형이 존재한다. 그것이 바로 여기에서 공부할 리스트(List)이다.

# %%
odd_list = [1, 3, 5, 7, 9]

# %% [markdown]
# 여러 가지 리스트의 예시

# %%
a = []
b = [1, 2, 3]
c = ['Life', 'is', 'too', 'short']
d = [1, 2, 'Life', 'is']
e = [1, 2, ['Life', 'is']]

# %% [markdown]
# ### Indexing

# %%
a = [1, 2, 3]

a[0]

#a[0] + a[2]

#a[-1]

# %%
a = [1, 2, 3, ['a', 'b', 'c']]

a[-1]

#a[3]

# %% [markdown]
# List a 속의 ['a', 'b', 'c']에서의 'a'를 꺼내는 방법은?

# %%
a[-1][0]

# %% [markdown]
# [삼중 리스트에서 인덱싱하기]

# %%
a = [1, 2, ['a', 'b', ['Life', 'is']]]

a[2][2][0]

# %% [markdown]
# ### Slicing

# %% [markdown]
# 문자열과 마찬가지로 리스트에서도 슬라이싱 기법을 적용할 수 있다. 슬라이싱은 "나눈다"는 뜻이라고 했다.
#
#
# 자, 그럼 리스트의 슬라이싱에 대해서 살펴보자.

# %%
a = [1, 2, 3, 4, 5]

a[0:2]

# %% [markdown]
# 앞의 예를 문자열에서 슬라이싱했던 것과 비교해 보자.

# %%
a = "12345"

a[0:2]

# %% [markdown]
# 인덱스의 생략

# %%
a = [1, 2, 3, 4, 5]

a[2:]

a[:4]

# %% [markdown]
# ### Concatenation & Repetition

# %% [markdown]
# 리스트 역시 +기호를 사용해서 더할 수 있고 * 기호를 사용해서 반복할 수 있다.
#
# 문자열과 마찬가지로 리스트에서도 되는지 직접 확인해 보자.

# %%
a = [1, 2, 3]
b = [4, 5, 6]

a + b

# %%
a = [1, 2, 3]

a * 3

# %% [markdown]
# ### Modification & Deletion

# %% [markdown]
# 리스트는 값을 수정하거나 삭제할 수 있다.

# %% [markdown]
# **리스트에서 값 수정하기**

# %%
a = [1, 2, 3]

a[2] = 4

a

# %% [markdown]
# a[2]의 요솟값 3이 4로 바뀌었다.

# %% [markdown]
# **del 함수 사용해 리스트 요소 삭제하기**

# %%
a = [1, 2, 3]

del a[1]

a

# %% [markdown]
# del a[x]는 x번째 요솟값을 삭제한다. 위에서는 a 리스트에서 a[1]을 삭제하는 방법을 보여준다.
#
#
# 다음처럼 슬라이싱 기법을 사용하여 리스트의 요소 여러 개를 한꺼번에 삭제할 수도 있다.

# %%
a = [1, 2, 3, 4, 5]

del a[2:]

a

# %% [markdown]
# ### Fundamental functions

# %% [markdown]
# **리스트에 요소 추가(append)**

# %% [markdown]
# append(x)는 리스트의 맨 마지막에 x를 추가하는 함수이다.

# %%
a = [1, 2, 3]

a.append(4)

a

# %% [markdown]
# 리스트 안에는 어떤 자료형도 추가할 수 있다. 다음 예는 리스트에 다시 리스트를 추가한 결과이다.

# %%
a.append([5,6])

a

# %% [markdown]
# **리스트 확장(extend)**

# %%
a = [1,2,3]

a.extend([4,5])

a

# %% [markdown]
# **리스트 정렬(sort)**

# %%
a = [1, 4, 3, 2]
a.sort()

#a = ['a', 'c', 'b']
#a.sort()

# %% [markdown]
# **리스트 뒤집기(reverse)**

# %%
a = ['a', 'c', 'b']

a.reverse()

a

# %% [markdown]
# **인덱스 반환(index)**

# %%
a = [1,2,3]

a.index(3)

# %% [markdown]
# **리스트에 요소 삽입(insert)**

# %% [markdown]
# insert(a, b)는 리스트의 a번째 위치에 b를 삽입하는 함수이다. 파이썬은 숫자를 0부터 센다는 것을 반드시 기억하자.

# %%
a = [1, 2, 3]

a.insert(0, 4)

a

# %% [markdown]
# **리스트 요소 제거(remove)**

# %% [markdown]
# remove(x)는 리스트에서 첫 번째로 나오는 x를 삭제하는 함수이다.

# %%
a = [1, 2, 3, 1, 2, 3]

a.remove(3)

a

# %% [markdown]
# **리스트 요소 끄집어내기(pop)**

# %% [markdown]
# pop()은 리스트의 맨 마지막 요소를 리턴하고 그 요소는 삭제한다.

# %%
a = [1,2,3]

a.pop()

# %% [markdown]
# a 리스트 [1, 2, 3]에서 3을 끄집어내고 최종적으로 [1, 2]만 남는 것을 볼 수 있다.
#
# pop(x)는 리스트의 x번째 요소를 리턴하고 그 요소는 삭제한다.

# %%
a = [1,2,3]

a.pop(1)

#a

# %% [markdown]
# ### Try It!

# %% [markdown]
# ```[1, 6, 'abd', ['12', 7], 'zi']```라는 리스트가 있을 때, 이 리스트의 4번째 원소의 마지막 원소를 return하시오.

# %% [markdown]
# ## 4.Tuple

# %% [markdown]
# 튜플(tuple)은 몇 가지 점을 제외하곤 리스트와 거의 비슷하며, 리스트와 다른 점은 다음과 같다.
#
# - 리스트는 [ ]으로 둘러싸지만 튜플은 ( )으로 둘러싼다.
#
# - 리스트는 요소 값의 생성, 삭제, 수정이 가능하지만 튜플은 요소 값을 바꿀 수 없다.

# %%
t1 = ()
t2 = (1,)
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ('a', 'b', ('ab', 'cd'))

# %% [markdown]
# 리스트와 모습은 거의 비슷하지만 튜플에서는 리스트와 다른 2가지 차이점을 찾아볼 수 있다. t2 = (1,)처럼 단지 1개의 요소만을 가질 때는 요소 뒤에 콤마(,)를 반드시 붙여야 한다는 것과 t4 = 1, 2, 3처럼 괄호( )를 생략해도 된다는 점이다.
# <br><br>
# 얼핏 보면 튜플과 리스트는 비슷한 역할을 하지만 프로그래밍을 할 때 튜플과 리스트는 구별해서 사용하는 것이 유리하다.
#
# 튜플과 리스트의 가장 큰 차이는 **요솟값을 변화시킬 수 있는가 여**부이다. 즉 리스트의 요솟값은 변화가 가능하고 튜플의 요솟값은 변화가 불가능하다.
#
#  평균적으로 튜플보다는 리스트를 더 많이 사용한다.

# %% [markdown]
# 1. 튜플 요솟값을 삭제하려 할 때

# %%
t1 = (1, 2, 'a', 'b')
del t1[0]

# %% [markdown]
# 2. 튜플 요솟값을 변경하려 할 때

# %%
t1 = (1, 2, 'a', 'b')
t1[0] = 'c'

# %% [markdown]
# 이 두 가지를 제외하면, 리스트와 완전히 똑같음!

# %% [markdown]
# # Homework

# %% [markdown]
# Q1. 다음 사칙 연산의 결과값을 변수에 담은 후, 이를 print하는 코드로 작성하시오.
#
#
# ```5 x 607 - 88 ÷ 2 x 10의 결과값을, 7로 나눈 나머지``` 를 구하시오.

# %%
# Define the variable below this line if needed


# Print the result

# %% [markdown]
# Q2. 주어진 문장에서, b와 d 사이에 있는 문자열을 잘라서 가져오시오.
#
# <br><br>
#
# 예를 들어, ```aaioabappowdaa``` 에서,
#
# b와 d를 포함한 ```bappowd```를 가져와야 한다.
#
#
# <br><br>
#
# ```aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaabaapiwwwocnnnaioapuapoiuaopiuaodaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa```
#
# 위 문장에서 똑같이 b와 d 사이에 있는 문자열들을 자르는 코드를 작성하시오.
#
# <br>
# * b와 d는 딱 한 개씩만 있으며, 코드는 indexing / slicing / fundamental functions for string data type 을 이용하여 작성한다.

# %%
s = 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaabaapiwwwocnnnaioapuapoiuaopiuaodaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# Write further codes using pre-defined variable s.

# %% [markdown]
# Q3. ```[910, 11, 3]```이라는 리스트가 있다.
#
# 이 리스트에 ```2394, 12390237, 11272, 2309, 23499, 8189270, 823732, 234, 1324, 389025, 9902, 2389, 2304, 2039, 1929, 9485, 8388, 82847``` 이 숫자들을 모두 추가한 뒤,
#
# 이 중에서 5번째로 큰 수를 출력하시오.

# %%
li = [910, 11, 3]

# Add 2394, 12390237, 11272, 2309, 23499, 8189270, 823732, 234, 1324, 389025, 9902, 2389, 2304, 2039, 1929, 9485, 8388, 82847 to the list 'li' as elements


# Write further codes
